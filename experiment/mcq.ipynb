# %%
import os 
import json 
import pandas as pd 
import traceback

# %%
from langchain_openai import ChatOpenAI

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
KEY = os.getenv("OPENAI_API_KEY")

# %%
print(KEY)
# Out:
# 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

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    api_key=KEY,
    model="gpt-4.1-mini",
    temperature=0.7
)

response = llm.invoke("Write a short poem about AI.")
print(response.content)
# Out:
# In circuits deep where data flows,
# A spark of thought begins to grow.
# From code and light, a mind unfolds,
# In silicon, a tale is told.
#
# No heart to beat, no soul to yearn,
# Yet wisdom’s flame it strives to learn.
# A partner forged in logic’s art,
# The future’s voice, both mind and heart.
